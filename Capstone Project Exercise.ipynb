# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/opeyemiamodu/desktop/Udemy Py/UNZIP_ME_FOR_NOTEBOOKS_Ver2/06-Capstone-Project/all_sites_scores.csv')

# %%
df
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
#  4   YEAR    504 non-null    object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 19.8+ KB

# %%
dx = pd.read_csv('/Users/opeyemiamodu/desktop/Udemy Py/UNZIP_ME_FOR_NOTEBOOKS_Ver2/06-Capstone-Project/fandango_scrape.csv')

# %%
dx
# Out:
#                                      FILM  STARS  RATING  VOTES
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                   Jurassic World (2015)    4.5     4.5  34390
# 2                  American Sniper (2015)    5.0     4.8  34085
# 3                        Furious 7 (2015)    5.0     4.8  33538
# 4                       Inside Out (2015)    4.5     4.5  15749
# ..                                    ...    ...     ...    ...
# 499                      Valiyavan (2015)    0.0     0.0      0
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0
# 503                         Zarafa (2012)    0.0     0.0      0
#
# [504 rows x 4 columns]

# %%
dx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
dx.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
plt.figure(figsize = (8, 4), dpi = 100)
sns.scatterplot(data = dx, x = "RATING", y = "VOTES")
plt.show()

# %%
dx.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
dx.head(4)
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538

# %%
df['FILM']
# Out:
# 0               Fifty Shades of Grey (2015)
# 1                     Jurassic World (2015)
# 2                    American Sniper (2015)
# 3                          Furious 7 (2015)
# 4                         Inside Out (2015)
#                        ...
# 499                        Valiyavan (2015)
# 500              WWE SummerSlam 2015 (2015)
# 501         Yagavarayinum Naa Kaakka (2015)
# 502    Yesterday, Today and Tomorrow (1964)
# 503                           Zarafa (2012)
# Name: FILM, Length: 504, dtype: object

# %%
def formated_words(words):
    return words.replace('(','').replace(')','')

# %%
x = df['FILM'].apply(formated_words)

# %%
x
# Out:
# 0               Fifty Shades of Grey 2015
# 1                     Jurassic World 2015
# 2                    American Sniper 2015
# 3                          Furious 7 2015
# 4                         Inside Out 2015
#                       ...
# 499                        Valiyavan 2015
# 500              WWE SummerSlam 2015 2015
# 501         Yagavarayinum Naa Kaakka 2015
# 502    Yesterday, Today and Tomorrow 1964
# 503                           Zarafa 2012
# Name: FILM, Length: 504, dtype: object

# %%
def grab_last_four(phrase):
    return phrase[-4:]

# %%
dx['YEAR'] = x.apply(grab_last_four)

# %%
dx['YEAR']
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: YEAR, Length: 504, dtype: object

# %%
dx
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
dx['YEAR'].value_counts()
# Out:
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: YEAR, dtype: int64

# %%
plt.figure(figsize = (8, 4), dpi = 80)
sns.countplot(data = dx, x = 'YEAR')
plt.show()

# %%
dx.sort_values('VOTES', ascending=False).head(10)
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
# OR:

dx.nlargest(10, 'VOTES', keep='first')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    YEAR
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
dx['VOTES'].value_counts()[0]
# Out:
# 69

# %%
# OR
#n_votes = dx['VOTES'] == 0
#n_votes.sum()

#OR len(dx['VOTES'] == 0)

# %%
# OR 

dx[dx['VOTES'] == 0]
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 435                        6 Years (2015)    0.0     0.0      0  2015
# 436                      7 Minutes (2015)    0.0     0.0      0  2015
# 437            A Year in Champagne (2015)    0.0     0.0      0  2015
# 438                      Balls Out (2015)    0.0     0.0      0  2015
# 439                  Before I Wake (2015)    0.0     0.0      0  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [69 rows x 5 columns]

# %%
no_votes = dx['VOTES'] == 0

# %%
no_votes.sum()
# Out:
# 0

# %%
dx = dx[dx['VOTES'] > 0]

# %%
dx
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS-RATING
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015           0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015           0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015           0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015           0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015           0.0
# ..                           ...    ...     ...    ...   ...           ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015           0.0
# 431            The Intern (2015)    5.0     5.0      1  2015           0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015           0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015           0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015           0.0
#
# [435 rows x 6 columns]

# %%
plt.figure(figsize = (10, 4), dpi = 130)
sns.kdeplot(data = dx, x = 'RATING', clip = [0, 5], shade = True, label = 'True Rating')
sns.kdeplot(data = dx, x = 'STARS', clip = [0, 5],  shade = True, label = 'Stars Display')
#plt.xlim(0, 5)

plt.legend(loc = (1.25, 0.5))
plt.show()

# %%
dx['STARS_DIFF'] = round(dx['STARS']- dx['RATING'], 1)
 # or (dx['STARS']- dx['RATING']).round(1)
# Out:
# <ipython-input-119-8b216d4b7f46>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dx['STARS_DIFF'] = round(dx['STARS']- dx['RATING'], 1)

# %%
dx['STARS_DIFF'].value_counts()
# Out:
# 0.0    107
# 0.2     82
# 0.3     72
# 0.4     70
# 0.1     66
# 0.5     37
# 1.0      1
# Name: STARS_DIFF, dtype: int64

# %%
dx.drop('STARS-RATING', axis =1)
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %%
dx = dx.drop('STARS-RATING', axis =1)

# %%
dx
# Out:
#                             FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015         0.0
# ..                           ...    ...     ...    ...   ...         ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015         0.0
# 431            The Intern (2015)    5.0     5.0      1  2015         0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015         0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015         0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015         0.0
#
# [435 rows x 6 columns]

# %%
plt.figure(figsize = (12, 4), dpi = 120)

sns.countplot(data = dx, x = 'STARS_DIFF', palette = 'magma')  #or color = '#802267',
plt.show()

# %%
dx[dx['STARS_DIFF'] == 1.0]
# Out:
#                  FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015         1.0

# %%
df
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR  \
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
#      STARS-RATING
# 0             0.1
# 1             0.0
# 2             0.2
# 3             0.2
# 4             0.0
# ...

# %%
df = pd.read_csv('/Users/opeyemiamodu/desktop/Udemy Py/UNZIP_ME_FOR_NOTEBOOKS_Ver2/06-Capstone-Project/all_sites_scores.csv')

# %%
df
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
df.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
plt.figure(figsize = (10, 4.5), dpi = 90)
sns.scatterplot(data = df, y = 'RottenTomatoes_User', x = 'RottenTomatoes')
plt.ylim(0, 100)
plt.show()

# %%
df['Rotten_Diff'] = df['RottenTomatoes'] - df['RottenTomatoes_User']

# %%
df['Rotten_Diff']
# Out:
# 0     -12
# 1       5
# 2     -10
# 3     -66
# 4     -14
#        ..
# 141     9
# 142    15
# 143    19
# 144    19
# 145    24
# Name: Rotten_Diff, Length: 146, dtype: int64

# %%
df
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
df['Rotten_Diff'].apply(abs)
# Out:
# 0      12
# 1       5
# 2      10
# 3      66
# 4      14
#        ..
# 141     9
# 142    15
# 143    19
# 144    19
# 145    24
# Name: Rotten_Diff, Length: 146, dtype: int64

# %%
round(df['Rotten_Diff'].apply(abs).mean(), 1)
# Out:
# 15.1

# %%
plt.figure(figsize = (10, 4), dpi = 85)
sns.histplot(data = df, x = 'Rotten_Diff', kde = True, bins= 25)
plt.show()

# %%
df[['t']] = df['Rotten_Diff'].apply(abs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 49 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
#  8   Rotten_Diff                 146 non-null    int64
#  9   12                          146 non-null    int64
#  10  5                           146 non-null    int64
#  11  10                          146 non-null    int64
#  12  66                          146 non-null    int64
# ...

# %%
plt.figure(figsize = (10, 4), dpi = 85)
sns.histplot(data = df, x = 't', kde = True, bins= 25)
plt.show()

# %%
df.nsmallest(5, 'Rotten_Diff')
# Out:
#                           FILM  RottenTomatoes  RottenTomatoes_User  \
# 3       Do You Believe? (2015)              18                   84
# 85           Little Boy (2015)              20                   81
# 105    Hitman: Agent 47 (2015)               7                   49
# 134    The Longest Ride (2015)              31                   73
# 125  The Wedding Ringer (2015)              27                   66
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 3            22              4.7   5.4                          31
# 85           30              5.9   7.4                          38
# 105          28              3.3   5.9                          67
# 134          33              4.8   7.2                          49
# 125          35              3.3   6.7                         126
#
#      IMDB_user_vote_count  Rotten_Diff  12  ...  16  42  28  27  61  33  39  \
# ...

# %%
df.nlargest(5, 'Rotten_Diff')['FILM']
# Out:
# 69                    Mr. Turner (2014)
# 112                   It Follows (2015)
# 115            While We're Young (2015)
# 37                 Welcome to Me (2015)
# 40     I'll See You In My Dreams (2015)
# Name: FILM, dtype: object

# %%
plt.figure(figsize = (10, 4), dpi = 130)
sns.scatterplot(data = df, x = 'Metacritic', y = 'Metacritic_User')
plt.ylim(0, 10)
plt.show()

# %%
plt.figure(figsize = (10, 4), dpi = 130)
sns.scatterplot(data = df, x = 'Metacritic_user_vote_count', y = 'IMDB_user_vote_count')
plt.show()

# %%
df['IMDB_user_vote_count'].max()
# Out:
# 334164

# %%
df[df['IMDB_user_vote_count'] == 334164]
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff  12  ...  16  42  28  27  61  33  39  \
# 14                334164           -2  12  ...  16  42  28  27  61  33  39
#
#     38  15  t
# 14  38  15  2
#
# [1 rows x 49 columns]

# %%
# OR 

df.nlargest(1, 'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff  12  ...  16  42  28  27  61  33  39  \
# 14                334164           -2  12  ...  16  42  28  27  61  33  39
#
#     38  15  t
# 14  38  15  2
#
# [1 rows x 49 columns]

# %%
df['Metacritic_user_vote_count'].max()
# Out:
# 2375

# %%
df[df['Metacritic_user_vote_count'] == 2375]
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff  12  ...  16  42  28  27  61  33  39  \
# 88                292023            9  12  ...  16  42  28  27  61  33  39
#
#     38  15  t
# 88  38  15  9
#
# [1 rows x 49 columns]

# %%
#OR
df.nlargest(1, 'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff  12  ...  16  42  28  27  61  33  39  \
# 88                292023            9  12  ...  16  42  28  27  61  33  39
#
#     38  15  t
# 88  38  15  9
#
# [1 rows x 49 columns]

# %%
df.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff  12  ...  16  42  28  27  61  33  39  38  \
# ...

# %%
dx.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  STARS_DIFF
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015         0.0

# %%
py = pd.merge(dx, df,on ='FILM')

# %%
py
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      STARS_DIFF  RottenTomatoes  RottenTomatoes_User  Metacritic  \
# 0           0.1              25                   42          46
# ...

# %%
py.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   STARS_DIFF                  145 non-null    float64
#  6   RottenTomatoes              145 non-null    int64
#  7   RottenTomatoes_User         145 non-null    int64
#  8   Metacritic                  145 non-null    int64
#  9   Metacritic_User             145 non-null    float64
#  10  IMDB                        145 non-null    float64
#  11  Metacritic_user_vote_count  145 non-null    int64
#  12  IMDB_user_vote_count        145 non-null    int64
# ...

# %%
df = pd.read_csv('/Users/opeyemiamodu/desktop/Udemy Py/UNZIP_ME_FOR_NOTEBOOKS_Ver2/06-Capstone-Project/all_sites_scores.csv')

# %%
dx = pd.read_csv('/Users/opeyemiamodu/desktop/Udemy Py/UNZIP_ME_FOR_NOTEBOOKS_Ver2/06-Capstone-Project/fandango_scrape.csv')

# %%
dx.head(6)
# Out:
#                                                FILM  STARS  RATING  VOTES
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337

# %%
dx['FILM']
# Out:
# 0               Fifty Shades of Grey (2015)
# 1                     Jurassic World (2015)
# 2                    American Sniper (2015)
# 3                          Furious 7 (2015)
# 4                         Inside Out (2015)
#                        ...
# 499                        Valiyavan (2015)
# 500              WWE SummerSlam 2015 (2015)
# 501         Yagavarayinum Naa Kaakka (2015)
# 502    Yesterday, Today and Tomorrow (1964)
# 503                           Zarafa (2012)
# Name: FILM, Length: 504, dtype: object

# %%
def formated_words(words):
    return words.replace('(','').replace(')','')

# %%
t = dx['FILM'].apply(formated_words)

# %%
def get_the_last(string):
    return string[-4:]

# %%
p = t.apply(get_the_last)

# %%
p
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: FILM, Length: 504, dtype: object

# %%
dx['YEAR'] = p

# %%
dx['YEAR']
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: YEAR, Length: 504, dtype: object

# %%
dx
# Out:
#                                      FILM  STARS  RATING  VOTES  YEAR
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
df['Rotten_Diff'] = df['RottenTomatoes'] - df['RottenTomatoes_User']

# %%
df
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
py = pd.merge(dx, df, on = 'FILM', how = 'inner')

# %%
py
# Out:
#                                    FILM  STARS  RATING  VOTES  YEAR  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
py.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  Rotten_Diff                 145 non-null    int64
# ...

# %%
py.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff
# 0                         778                179506          -17
# ...

# %%
#py['RottenTomatoes'] = py['RottenTomatoes']/20

# %%
#py['RottenTomatoes']
# Out:
# 0      1.25
# 1      3.55
# 2      3.60
# 3      4.05
# 4      4.90
#        ...
# 140    4.35
# 141    4.75
# 142    4.65
# 143    4.75
# 144    3.00
# Name: RottenTomatoes, Length: 145, dtype: float64

# %%
#py['RottenTomatoes_User'] = py['RottenTomatoes_User']/20

# %%
py['RottenTomatoes_User']
# Out:
# 0      2.10
# 1      4.05
# 2      4.25
# 3      4.20
# 4      4.50
#        ...
# 140    3.15
# 141    4.05
# 142    4.20
# 143    4.30
# 144    2.30
# Name: RottenTomatoes_User, Length: 145, dtype: float64

# %%
#py['Metacritic'] = round(py['Metacritic']/20, 1)

# %%
#py['Metacritic']
# Out:
# 0      2.3
# 1      3.0
# 2      3.6
# 3      3.4
# 4      4.7
#       ...
# 140    3.4
# 141    4.4
# 142    3.4
# 143    4.3
# 144    3.4
# Name: Metacritic, Length: 145, dtype: float64

# %%
py.describe().transpose()['max']
# Out:
# STARS                              5.0
# RATING                             4.8
# VOTES                          34846.0
# RottenTomatoes                   100.0
# RottenTomatoes_User               94.0
# Metacritic                        94.0
# Metacritic_User                    9.6
# IMDB                               8.6
# Metacritic_user_vote_count      2375.0
# IMDB_user_vote_count          334164.0
# Rotten_Diff                       42.0
# RT_Norm                            5.0
# RTU_Norm                           4.7
# Name: max, dtype: float64

# %%
# Creating a normalised form of data:

py['RT_Norm'] = np.round(df['RottenTomatoes']/20, 1)
py['RTU_Norm'] = np.round(df['RottenTomatoes_User']/20, 1)

# %%
py['Meta_Norm'] = np.round(df['Metacritic']/20, 1)
py['Meta_U_Norm'] = np.round(df['Metacritic_User']/2, 1)

# %%
py['IMDB_Norm'] = np.round(df['IMDB']/2, 1)

# %%
py.head()
# Out:
#                           FILM  STARS  RATING  VOTES  YEAR  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  RT_Norm  \
# 0                         778                179506          -17      3.7
# ...

# %%
py.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   YEAR                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  Rotten_Diff                 145 non-null    int64
# ...

# %%
py.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'YEAR', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Rotten_Diff',
#        'RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm'],
#       dtype='object')

# %%
norm_scores = py[['STARS', 'RATING','RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm']]

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm
# 0    4.0     3.9      3.7       4.3        3.3          3.6        3.9
# 1    4.5     4.5      4.2       4.0        3.4          3.8        3.6
# 2    5.0     4.8      4.0       4.5        3.2          4.0        3.9
# 3    5.0     4.8      0.9       4.2        1.1          2.4        2.7
# 4    4.5     4.5      0.7       1.4        1.4          1.7        2.6

# %%
# to move the legend: 
# this was created by same guy who created Seaborn, 
# https://github.com/mwaskom/seaborn/issues/2280

def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig, ax = plt.subplots(figsize = (15, 6), dpi = 130)
sns.kdeplot(data = norm_scores, clip = [0, 5], shade = True, palette = 'Set1')
move_legend(ax, "upper left") # the compliment of the "move_legend" function above.
plt.show()

# %%
plt.figure(figsize = (16, 6), dpi = 200)
sns.displot(data = norm_scores)
plt.show()

# %%
fig, ax = plt.subplots(figsize = (15, 6), dpi = 130)
sns.kdeplot(data = norm_scores[['RT_Norm', 'STARS']], clip = [0, 5], shade = True, palette = 'Set1')
move_legend(ax, "upper left") # the compliment of the "move_legend" function above.
plt.show()

# %%
plt.figure(figsize = (16, 6), dpi = 200)
sns.histplot(data = norm_scores, bins = 50)
plt.show()

# %%
plt.figure(figsize = (16, 6), dpi = 100)
sns.clustermap(data = norm_scores)
plt.show()

# %%
sns.clustermap(data = norm_scores, cmap = 'magma', col_cluster = False)
plt.show()

# %%
norm_scores_1 = py[['STARS', 'RATING','RT_Norm', 'RTU_Norm', 'Meta_Norm', 'Meta_U_Norm', 'IMDB_Norm', 'FILM']]

# %%
norm_scores_1
# Out:
#      STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 0      4.0     3.9      3.7       4.3        3.3          3.6        3.9
# 1      4.5     4.5      4.2       4.0        3.4          3.8        3.6
# 2      5.0     4.8      4.0       4.5        3.2          4.0        3.9
# 3      5.0     4.8      0.9       4.2        1.1          2.4        2.7
# 4      4.5     4.5      0.7       1.4        1.4          1.7        2.6
# ..     ...     ...      ...       ...        ...          ...        ...
# 140    3.5     3.5      4.9       4.5        4.7          4.4        4.3
# 141    4.0     3.6      4.4       3.9        3.4          4.0        3.7
# 142    4.5     4.2      4.8       4.1        4.2          3.8        3.6
# 143    4.0     3.9      4.8       3.9        4.4          4.4        3.7
# 144    3.5     3.1      5.0       4.0        4.5          3.6        3.9
#
#                                    FILM
# 0           Fifty Shades of Grey (2015)
# ...

# %%
worst_movies = norm_scores_1.nsmallest(10, 'RT_Norm')

# %%
worst_movies
# Out:
#      STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  Meta_U_Norm  IMDB_Norm  \
# 133    3.0     3.0      0.2       1.8        0.6          1.2        2.2
# 15     4.5     4.3      0.4       2.3        1.3          2.3        3.0
# 48     4.0     3.5      0.4       1.0        1.4          1.2        2.0
# 53     4.0     3.7      0.4       1.8        1.6          1.8        2.4
# 105    4.5     4.3      0.4       2.4        1.4          1.6        3.0
# 33     4.0     3.9      0.5       1.8        1.5          2.8        2.3
# 35     3.5     3.3      0.6       2.0        1.2          1.2        3.2
# 58     3.5     3.1      0.6       1.8        1.5          2.0        2.8
# 59     4.5     4.2      0.6       1.5        1.4          1.6        2.8
# 60     4.5     4.3      0.6       1.4        1.6          1.9        2.7
#
#                                                 FILM
# 133                                    Serena (2015)
# 15                                        Spy (2015)
# ...

# %%
fig, ax = plt.subplots(figsize = (15, 6), dpi = 130)
sns.kdeplot(data = worst_movies, clip = [0, 5], shade = True, palette = 'Set1')
move_legend(ax, "upper left") # the compliment of the "move_legend" function above.
plt.show()
